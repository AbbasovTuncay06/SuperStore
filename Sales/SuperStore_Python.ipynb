# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\cahan\OneDrive\Desktop\Sales\Messy-SuperStore Data.csv")  
            
df

df.shape
# Out:
# (14204, 12)

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
df.tail(10)
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 14194           FDA01        15.00              reg         0.054463
# 14195           NCH42         6.86          Low Fat         0.036594
# 14196           FDF46         7.07          Low Fat         0.094053
# 14197           DRL35        15.70          Low Fat         0.030704
# 14198           FDW46        13.00          Regular         0.070411
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 14194              Canned   59.5904            OUT049
# 14195           Household  231.1010            OUT049
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# ...

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.select_dtypes(include="number")
# Out:
#        Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0             9.30         0.016047  249.8092                       1999
# 1             5.92         0.019278   48.2692                       2009
# 2            17.50         0.016760  141.6180                       1999
# 3            19.20         0.000000  182.0950                       1998
# 4             8.93         0.000000   53.8614                       1987
# ...            ...              ...       ...                        ...
# 14199        10.50         0.013496  141.3154                       1997
# 14200         7.60         0.142991  169.1448                       2009
# 14201        10.00         0.073529  118.7440                       2002
# 14202        15.30         0.000000  214.6218                       2007
# 14203         9.50         0.104720   79.7960                       2002
#
#        Item_Outlet_Sales
# 0            3735.138000
# 1             443.422800
# ...

# %%
df.select_dtypes(include="object")
# Out:
#       Item_Identifier Item_Fat_Content              Item_Type  \
# 0               FDA15          Low Fat                  Dairy
# 1               DRC01          Regular            Soft Drinks
# 2               FDN15          Low Fat                   Meat
# 3               FDX07          Regular  Fruits and Vegetables
# 4               NCD19          Low Fat              Household
# ...               ...              ...                    ...
# 14199           FDB58          Regular            Snack Foods
# 14200           FDD47          Regular          Starchy Foods
# 14201           NCO17          Low Fat     Health and Hygiene
# 14202           FDJ26          Regular                 Canned
# 14203           FDU37          Regular                 Canned
#
#       Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# 0                OUT049      Medium               Tier 1  Supermarket Type1
# ...

# %%
df["Item_Type"].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
df2=df.dropna(subset=["Item_Weight"])

df2=df2.copy()

# %%
df2["Outlet_Size"]=df2["Outlet_Size"].fillna("Unknown")
df2
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# ...

# %%
df2.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df2["Item_Visibility"]=df2["Item_Visibility"].round(3)
df2
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat            0.016
# 1               DRC01         5.92          Regular            0.019
# 2               FDN15        17.50          Low Fat            0.017
# 3               FDX07        19.20          Regular            0.000
# 4               NCD19         8.93          Low Fat            0.000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular            0.013
# 14200           FDD47         7.60          Regular            0.143
# 14201           NCO17        10.00          Low Fat            0.074
# 14202           FDJ26        15.30          Regular            0.000
# 14203           FDU37         9.50          Regular            0.105
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# ...

# %%
df2["Item_Type"]=df2["Item_Type"].str.strip()
df2
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat            0.016
# 1               DRC01         5.92          Regular            0.019
# 2               FDN15        17.50          Low Fat            0.017
# 3               FDX07        19.20          Regular            0.000
# 4               NCD19         8.93          Low Fat            0.000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular            0.013
# 14200           FDD47         7.60          Regular            0.143
# 14201           NCO17        10.00          Low Fat            0.074
# 14202           FDJ26        15.30          Regular            0.000
# 14203           FDU37         9.50          Regular            0.105
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# ...

# %%
df2["Item_Fat_Content"]=df2["Item_Fat_Content"].replace("LF","Low Fat")
df2["Item_Fat_Content"]=df2["Item_Fat_Content"].replace("reg","Regular")
df2
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat            0.016
# 1               DRC01         5.92          Regular            0.019
# 2               FDN15        17.50          Low Fat            0.017
# 3               FDX07        19.20          Regular            0.000
# 4               NCD19         8.93          Low Fat            0.000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular            0.013
# 14200           FDD47         7.60          Regular            0.143
# 14201           NCO17        10.00          Low Fat            0.074
# 14202           FDJ26        15.30          Regular            0.000
# 14203           FDU37         9.50          Regular            0.105
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# ...

# %%
df2["Item_Fat_Content"].unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %%
df2["Item_Fat_Content"]=df2["Item_Fat_Content"].str.title()

# %% [markdown]
# df2.duplicated().sum

# %%
df2.drop_duplicates()
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat            0.016
# 1               DRC01         5.92          Regular            0.019
# 2               FDN15        17.50          Low Fat            0.017
# 3               FDX07        19.20          Regular            0.000
# 4               NCD19         8.93          Low Fat            0.000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular            0.013
# 14200           FDD47         7.60          Regular            0.143
# 14201           NCO17        10.00          Low Fat            0.074
# 14202           FDJ26        15.30          Regular            0.000
# 14203           FDU37         9.50          Regular            0.105
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# ...

# %%
df2[df2["Item_MRP"]>200]
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15        9.300          Low Fat            0.016
# 19              FDU02       13.350          Low Fat            0.102
# 20              FDN22       18.850          Regular            0.138
# 32              FDP33       18.700          Low Fat            0.000
# 40              FDU02       13.350          Low Fat            0.103
# ...               ...          ...              ...              ...
# 14183           FDK22        9.800          Low Fat            0.026
# 14185           FDK22        9.800          Low Fat            0.026
# 14193           FDO03       10.395          Regular            0.037
# 14195           NCH42        6.860          Low Fat            0.037
# 14202           FDJ26       15.300          Regular            0.000
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df2[df2["Item_Visibility"]<0.1]
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat            0.016
# 1               DRC01         5.92          Regular            0.019
# 2               FDN15        17.50          Low Fat            0.017
# 3               FDX07        19.20          Regular            0.000
# 4               NCD19         8.93          Low Fat            0.000
# ...               ...          ...              ...              ...
# 14197           DRL35        15.70          Low Fat            0.031
# 14198           FDW46        13.00          Regular            0.070
# 14199           FDB58        10.50          Regular            0.013
# 14201           NCO17        10.00          Low Fat            0.074
# 14202           FDJ26        15.30          Regular            0.000
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# ...

# %%
df2[df2["Item_Type"]=="Dairy"]
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15        9.300          Low Fat            0.016
# 11              FDA03       18.500          Regular            0.045
# 19              FDU02       13.350          Low Fat            0.102
# 28              FDE51        5.925          Regular            0.161
# 30              FDV38       19.250          Low Fat            0.170
# ...               ...          ...              ...              ...
# 14094           FDI15       13.800          Low Fat            0.237
# 14111           FDJ15       11.350          Regular            0.023
# 14143           FDB15       10.895          Low Fat            0.137
# 14154           FDA03       18.500          Regular            0.046
# 14172           DRH03       17.250          Low Fat            0.035
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df2[(df2["Item_Type"]=="Dairy") & (df2["Item_MRP"]>200)]
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15        9.300          Low Fat            0.016
# 19              FDU02       13.350          Low Fat            0.102
# 40              FDU02       13.350          Low Fat            0.103
# 110             FDD03       13.300          Low Fat            0.080
# 211             DRC27       13.800          Low Fat            0.058
# ...               ...          ...              ...              ...
# 13979           FDI15       13.800          Low Fat            0.142
# 14019           FDZ26       11.600          Regular            0.144
# 14064           FDF39       14.850          Regular            0.020
# 14094           FDI15       13.800          Low Fat            0.237
# 14143           FDB15       10.895          Low Fat            0.137
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df2.groupby("Item_Type")["Item_Outlet_Sales"].mean()
# Out:
# Item_Type
# Baking Goods             1846.257592
# Breads                   2090.407126
# Breakfast                1943.309005
# Canned                   2041.646558
# Dairy                    2079.893126
# Frozen Foods             1950.674620
# Fruits and Vegetables    2082.010720
# Hard Drinks              1962.870051
# Health and Hygiene       1929.759640
# Household                2109.444205
# Meat                     2038.120445
# Others                   1942.294310
# Seafood                  2418.089837
# Snack Foods              2115.964250
# Soft Drinks              1943.673288
# Starchy Foods            2208.732809
# Name: Item_Outlet_Sales, dtype: float64

# %%
df2.groupby("Item_Type")["Item_Outlet_Sales"].sum()
# Out:
# Item_Type
# Baking Goods             1.661632e+06
# Breads                   7.170096e+05
# Breakfast                2.953830e+05
# Canned                   1.833399e+06
# Dairy                    1.957179e+06
# Frozen Foods             2.292043e+06
# Fruits and Vegetables    3.470712e+06
# Hard Drinks              5.947496e+05
# Health and Hygiene       1.370129e+06
# Household                2.710636e+06
# Meat                     1.237139e+06
# Others                   4.428431e+05
# Seafood                  1.765206e+05
# Snack Foods              3.497689e+06
# Soft Drinks              1.172035e+06
# Starchy Foods            5.013823e+05
# Name: Item_Outlet_Sales, dtype: float64

# %%
df2.groupby("Item_Type").size()
# Out:
# Item_Type
# Baking Goods              900
# Breads                    343
# Breakfast                 152
# Canned                    898
# Dairy                     941
# Frozen Foods             1175
# Fruits and Vegetables    1667
# Hard Drinks               303
# Health and Hygiene        710
# Household                1285
# Meat                      607
# Others                    228
# Seafood                    73
# Snack Foods              1653
# Soft Drinks               603
# Starchy Foods             227
# dtype: int64

# %%
df2.groupby("Item_Fat_Content")["Item_MRP"].mean()
# Out:
# Item_Fat_Content
# Low Fat    141.281146
# Regular    140.550426
# Name: Item_MRP, dtype: float64

# %%
df.groupby("Outlet_Type")["Item_Outlet_Sales"].max()
# Out:
# Outlet_Type
# Grocery Store         1775.6886
# Supermarket Type1    10256.6490
# Supermarket Type2     6768.5228
# Supermarket Type3    13086.9648
# Name: Item_Outlet_Sales, dtype: float64

# %%
df2.groupby("Item_Type")["Item_Outlet_Sales"].agg(["min","max","mean"])
# Out:
#                             min         max         mean
# Item_Type
# Baking Goods            48.6034   7931.6754  1846.257592
# Breads                  35.2874   7064.8038  2090.407126
# Breakfast               39.9480   6930.9780  1943.309005
# Canned                  41.9454   7590.1200  2041.646558
# Dairy                   47.2718  10256.6490  2079.893126
# Frozen Foods            36.6190   9275.9256  1950.674620
# Fruits and Vegetables   45.2744   8994.9580  2082.010720
# Hard Drinks             71.9064   7843.1240  1962.870051
# Health and Hygiene      37.9506   9779.9362  1929.759640
# Household               33.2900   7240.5750  2109.444205
# Meat                    47.9376   6729.9064  2038.120445
# Others                  55.2614   6008.8450  1942.294310
# Seafood                158.4604   6503.5344  2418.089837
# Snack Foods             34.7548   9069.5276  2115.964250
# Soft Drinks             33.2900   7696.6480  1943.673288
# ...

# %%
df2.groupby("Item_Type")["Item_Outlet_Sales"].max().sort_values(ascending=False)
# Out:
# Item_Type
# Dairy                    10256.6490
# Health and Hygiene        9779.9362
# Frozen Foods              9275.9256
# Snack Foods               9069.5276
# Fruits and Vegetables     8994.9580
# Starchy Foods             8132.0812
# Baking Goods              7931.6754
# Hard Drinks               7843.1240
# Soft Drinks               7696.6480
# Canned                    7590.1200
# Household                 7240.5750
# Breads                    7064.8038
# Breakfast                 6930.9780
# Meat                      6729.9064
# Seafood                   6503.5344
# Others                    6008.8450
# Name: Item_Outlet_Sales, dtype: float64

# %%
df2.groupby("Outlet_Identifier").count()
df2.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df2.groupby("Item_Type")["Item_Outlet_Sales"].median()
# Out:
# Item_Type
# Baking Goods             1595.104616
# Breads                   1845.597600
# Breakfast                1668.135715
# Canned                   1765.624924
# Dairy                    1737.738000
# Frozen Foods             1641.862800
# Fruits and Vegetables    1840.914524
# Hard Drinks              1643.988156
# Health and Hygiene       1786.764062
# Household                1973.431200
# Meat                     1813.639200
# Others                   1809.977300
# Seafood                  2247.075000
# Snack Foods              1949.969524
# Soft Drinks              1701.784800
# Starchy Foods            2125.183864
# Name: Item_Outlet_Sales, dtype: float64

# %%
df2.groupby(["Item_Fat_Content","Item_Type"])["Item_Outlet_Sales"].mean()
# Out:
# Item_Fat_Content  Item_Type
# Low Fat           Baking Goods             1724.789957
#                   Breads                   2015.727199
#                   Breakfast                2258.138185
#                   Canned                   2050.259386
#                   Dairy                    2056.276293
#                   Frozen Foods             1909.373392
#                   Fruits and Vegetables    1953.114190
#                   Hard Drinks              1962.870051
#                   Health and Hygiene       1929.759640
#                   Household                2109.444205
#                   Meat                     1919.559177
#                   Others                   1942.294310
#                   Seafood                  1827.377421
#                   Snack Foods              2240.386098
#                   Soft Drinks              1998.577259
#                   Starchy Foods            2304.100404
# Regular           Baking Goods             1965.584827
# ...

# %%
df2.sort_values("Item_Outlet_Sales",ascending=False)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4888           FDF39       14.850          Regular            0.019
# 4289           NCM05        6.825          Low Fat            0.060
# 4961           FDK03       12.600          Regular            0.074
# 997            FDK28        5.695          Low Fat            0.066
# 6409           FDA21       13.650          Low Fat            0.036
# ...              ...          ...              ...              ...
# 4265           FDS40       15.350          Low Fat            0.023
# 7388           FDQ47        7.155          Regular            0.282
# 9197           FDU21       11.800          Regular            0.128
# 906            DRK12        9.500          Low Fat            0.000
# 6950           NCR42        9.105          Low Fat            0.064
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 4888               Dairy  261.2910            OUT013
# ...

# %%
df2.sort_values("Item_MRP",ascending=False).head(10)
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4802            FDS13        6.465          Low Fat            0.125
# 5884            FDR25       17.000          Regular            0.140
# 4159            FDK51       19.850          Low Fat            0.009
# 5254            NCS29        9.000          Low Fat            0.069
# 5558            NCS29        9.000          Low Fat            0.070
# 11903           FDR25       17.000          Regular            0.139
# 12319           FDR25       17.000          Regular            0.140
# 11406           NCM05        6.825          Low Fat            0.060
# 4877            NCS29        9.000          Low Fat            0.070
# 13513           FDY14       10.300          Low Fat            0.117
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 4802               Canned  266.8884            OUT017
# 5884               Canned  266.8884            OUT046
# ...

# %%
df2["Item_Visibility"]=df2["Item_Visibility"].apply(
    lambda x: "Low" if x<0.1 and x!=0 else ( "High" if x>=0.1 else "Unknown"))

# %%
df2
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content Item_Visibility  \
# 0               FDA15         9.30          Low Fat             Low
# 1               DRC01         5.92          Regular             Low
# 2               FDN15        17.50          Low Fat             Low
# 3               FDX07        19.20          Regular         Unknown
# 4               NCD19         8.93          Low Fat         Unknown
# ...               ...          ...              ...             ...
# 14199           FDB58        10.50          Regular             Low
# 14200           FDD47         7.60          Regular            High
# 14201           NCO17        10.00          Low Fat             Low
# 14202           FDJ26        15.30          Regular         Unknown
# 14203           FDU37         9.50          Regular            High
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# ...

# %%
df2 = df2.merge(
    df[["Item_Identifier", "Item_Visibility"]]
      .rename(columns={"Item_Visibility": "Visibility"}),
    on="Item_Identifier",
    how="left"
)

# %%
df3=df2.drop("Visibility_y",axis=1)

# %%
df3.drop("Visibility_x",axis=1)
# Out:
#         Item_Identifier  Item_Weight Item_Fat_Content Item_Visibility  \
# 0                 FDA15          9.3          Low Fat             Low
# 1                 FDA15          9.3          Low Fat             Low
# 2                 FDA15          9.3          Low Fat             Low
# 3                 FDA15          9.3          Low Fat             Low
# 4                 FDA15          9.3          Low Fat             Low
# ...                 ...          ...              ...             ...
# 9179204           FDU37          9.5          Regular            High
# 9179205           FDU37          9.5          Regular            High
# 9179206           FDU37          9.5          Regular            High
# 9179207           FDU37          9.5          Regular            High
# 9179208           FDU37          9.5          Regular            High
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df3=df3.copy()

# %%
df3
# Out:
#         Item_Identifier  Item_Weight Item_Fat_Content Item_Visibility  \
# 0                 FDA15          9.3          Low Fat             Low
# 1                 FDA15          9.3          Low Fat             Low
# 2                 FDA15          9.3          Low Fat             Low
# 3                 FDA15          9.3          Low Fat             Low
# 4                 FDA15          9.3          Low Fat             Low
# ...                 ...          ...              ...             ...
# 9179204           FDU37          9.5          Regular            High
# 9179205           FDU37          9.5          Regular            High
# 9179206           FDU37          9.5          Regular            High
# 9179207           FDU37          9.5          Regular            High
# 9179208           FDU37          9.5          Regular            High
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df3["High_sales"]=df3["Item_Outlet_Sales"]>3000
df3
# Out:
#         Item_Identifier  Item_Weight Item_Fat_Content Item_Visibility  \
# 0                 FDA15          9.3          Low Fat             Low
# 1                 FDA15          9.3          Low Fat             Low
# 2                 FDA15          9.3          Low Fat             Low
# 3                 FDA15          9.3          Low Fat             Low
# 4                 FDA15          9.3          Low Fat             Low
# ...                 ...          ...              ...             ...
# 9179204           FDU37          9.5          Regular            High
# 9179205           FDU37          9.5          Regular            High
# 9179206           FDU37          9.5          Regular            High
# 9179207           FDU37          9.5          Regular            High
# 9179208           FDU37          9.5          Regular            High
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df3.to_csv("C:/Users/cahan/OneDrive/Desktop/Clean_SuperStore_Data.csv", index=False)
